# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib

# %%
data = np.load('/content/drive/MyDrive/driver_drowsiness_detection_modified/driver_drowsiness_detection/dataset_compressed.npz', allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']

X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img
    
print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {0, 1}

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161,)
# (291, 32, 32, 3)
# (291,)
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_closed = np.where(Y==0)
img_closed = X[idx_closed[0][0]]
plt.imshow(img_closed)
plt.title('Image of Closed Eye representing Driver is sleeping')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_open = np.where(Y==1)
img_open = X[idx_open[0][0]]
plt.imshow(img_open)
plt.title('Image of Open Eye representing Driver is not sleeping')
plt.axis('off')
plt.show()

# %%
unique_train, count = np.unique(Y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Number of training images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(Y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Number of training images per category:")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam(0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 8, 8, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv5 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_4 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv6 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv7 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_6 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  fc1 (Dense)                 (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  fc3 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 227,554
# Trainable params: 226,786
# Non-trainable params: 768
# _________________________________________________________________

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.4893 - accuracy: 0.7640 - val_loss: 0.3966 - val_accuracy: 0.8454
# Epoch 2/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.4767 - accuracy: 0.7717 - val_loss: 0.3748 - val_accuracy: 0.8454
# Epoch 3/200
# 10/10 [==============================] - 7s 748ms/step - loss: 0.4692 - accuracy: 0.7847 - val_loss: 0.3584 - val_accuracy: 0.8454
# Epoch 4/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.4439 - accuracy: 0.8036 - val_loss: 0.3367 - val_accuracy: 0.8591
# Epoch 5/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.4745 - accuracy: 0.7855 - val_loss: 0.3187 - val_accuracy: 0.8729
# Epoch 6/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.4383 - accuracy: 0.8028 - val_loss: 0.2995 - val_accuracy: 0.8866
# Epoch 7/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.4100 - accuracy: 0.8260 - val_loss: 0.2816 - val_accuracy: 0.9003
# Epoch 8/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.3984 - accuracy: 0.8355 - val_loss: 0.2666 - val_accuracy: 0.9141
# Epoch 9/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.3932 - accuracy: 0.8295 - val_loss: 0.2559 - val_accuracy: 0.9141
# Epoch 10/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.3586 - accuracy: 0.8484 - val_loss: 0.2468 - val_accuracy: 0.9141
# Epoch 11/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.3758 - accuracy: 0.8415 - val_loss: 0.2393 - val_accuracy: 0.9107
# Epoch 12/200
# 10/10 [==============================] - 7s 677ms/step - loss: 0.3555 - accuracy: 0.8458 - val_loss: 0.2268 - val_accuracy: 0.9175
# Epoch 13/200
# 10/10 [==============================] - 7s 742ms/step - loss: 0.3615 - accuracy: 0.8570 - val_loss: 0.2139 - val_accuracy: 0.9278
# Epoch 14/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.3500 - accuracy: 0.8648 - val_loss: 0.1986 - val_accuracy: 0.9381
# Epoch 15/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.3424 - accuracy: 0.8665 - val_loss: 0.1870 - val_accuracy: 0.9416
# Epoch 16/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.3519 - accuracy: 0.8527 - val_loss: 0.1792 - val_accuracy: 0.9519
# Epoch 17/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.3232 - accuracy: 0.8760 - val_loss: 0.1731 - val_accuracy: 0.9519
# Epoch 18/200
# 10/10 [==============================] - 7s 751ms/step - loss: 0.3205 - accuracy: 0.8699 - val_loss: 0.1739 - val_accuracy: 0.9313
# Epoch 19/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.3414 - accuracy: 0.8811 - val_loss: 0.1636 - val_accuracy: 0.9485
# Epoch 20/200
# 10/10 [==============================] - 7s 671ms/step - loss: 0
200
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0276 - accuracy: 0.9922 - val_loss: 0.0141 - val_accuracy: 0.9966
# Epoch 181/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0355 - accuracy: 0.9862 - val_loss: 0.0178 - val_accuracy: 0.9931
# Epoch 182/200
# 10/10 [==============================] - 7s 748ms/step - loss: 0.0386 - accuracy: 0.9862 - val_loss: 0.0209 - val_accuracy: 0.9931
# Epoch 183/200
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0232 - accuracy: 0.9914 - val_loss: 0.0191 - val_accuracy: 0.9966
# Epoch 184/200
# 10/10 [==============================] - 7s 678ms/step - loss: 0.0302 - accuracy: 0.9888 - val_loss: 0.0139 - val_accuracy: 0.9931
# Epoch 185/200
# 10/10 [==============================] - 7s 678ms/step - loss: 0.0299 - accuracy: 0.9888 - val_loss: 0.0141 - val_accuracy: 0.9931
# Epoch 186/200
# 10/10 [==============================] - 7s 679ms/step - loss: 0.0205 - accuracy: 0.9914 - val_loss: 0.0136 - val_accuracy: 0.9966
# Epoch 187/200
# 10/10 [==============================] - 7s 681ms/step - loss: 0.0310 - accuracy: 0.9879 - val_loss: 0.0146 - val_accuracy: 0.9966
# Epoch 188/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0305 - accuracy: 0.9922 - val_loss: 0.0169 - val_accuracy: 0.9966
# Epoch 189/200
# 10/10 [==============================] - 7s 748ms/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.0146 - val_accuracy: 0.9931
# Epoch 190/200
# 10/10 [==============================] - 7s 677ms/step - loss: 0.0237 - accuracy: 0.9897 - val_loss: 0.0137 - val_accuracy: 0.9931
# Epoch 191/200
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0284 - accuracy: 0.9888 - val_loss: 0.0160 - val_accuracy: 0.9931
# Epoch 192/200
# 10/10 [==============================] - 7s 689ms/step - loss: 0.0220 - accuracy: 0.9940 - val_loss: 0.0178 - val_accuracy: 0.9931
# Epoch 193/200
# 10/10 [==============================] - 7s 677ms/step - loss: 0.0268 - accuracy: 0.9914 - val_loss: 0.0178 - val_accuracy: 0.9931
# Epoch 194/200
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0296 - accuracy: 0.9879 - val_loss: 0.0189 - val_accuracy: 0.9966
# Epoch 195/200
# 10/10 [==============================] - 7s 682ms/step - loss: 0.0352 - accuracy: 0.9845 - val_loss: 0.0169 - val_accuracy: 0.9931
# Epoch 196/200
# 10/10 [==============================] - 7s 677ms/step - loss: 0.0259 - accuracy: 0.9914 - val_loss: 0.0174 - val_accuracy: 0.9931
# Epoch 197/200
# 10/10 [==============================] - 7s 677ms/step - loss: 0.0198 - accuracy: 0.9931 - val_loss: 0.0188 - val_accuracy: 0.9931
# Epoch 198/200
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0168 - accuracy: 0.9974 - val_loss: 0.0212 - val_accuracy: 0.9931
# Epoch 199/200
# 10/10 [==============================] - 7s 682ms/step - loss: 0.0214 - accuracy: 0.9905 - val_loss: 0.0221 - val_accuracy: 0.9931
# Epoch 200/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.0182 - val_accuracy: 0.9931

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0182 - accuracy: 0.9931
# Test Set Accuracy: 0.993127167224884
# Test Set Loss: 0.018202761188149452

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       150
#            1       0.99      0.99      0.99       141
#
#     accuracy                           0.99       291
#    macro avg       0.99      0.99      0.99       291
# weighted avg       0.99      0.99      0.99       291

# %%
matrix = confusion_matrix(Y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')

# %%
model.save('/content/drive/MyDrive/driver_drowsiness_detection_modified/model/Driver_Drowsiness_Detection.h5')

# %%
labels = ['Closed', 'Open']
img_closed1 = cv2.imread('/content/drive/MyDrive/driver_drowsiness_detection_modified/driver_drowsiness_detection/closed_eye.jpg')
img_closed2 = cv2.imread('/content/drive/MyDrive/driver_drowsiness_detection_modified/driver_drowsiness_detection/closed_eye2.jpg')
img_open1 = cv2.imread('/content/drive/MyDrive/driver_drowsiness_detection_modified/driver_drowsiness_detection/open_eye.jpg')
img_open2 = cv2.imread('/content/drive/MyDrive/driver_drowsiness_detection_modified/driver_drowsiness_detection/open_eye2.jpg')

img_closed1 = cv2.resize(img_closed1, (32, 32))
img_closed2 = cv2.resize(img_closed2, (32, 32))
img_open1 = cv2.resize(img_open1, (32, 32))
img_open2 = cv2.resize(img_open2, (32, 32))

img_closed1 = np.array(img_closed1)
img_closed2 = np.array(img_closed2)
img_open1 = np.array(img_open1)
img_open2 = np.array(img_open2)

img_closed1 = np.expand_dims(img_closed1, axis=0)
img_closed2 = np.expand_dims(img_closed2, axis=0)
img_open1 = np.expand_dims(img_open1, axis=0)
img_open2 = np.expand_dims(img_open2, axis=0)

# %%
ypred_closed1 = model.predict(img_closed1)
ypred_closed2 = model.predict(img_closed2)
ypred_open1 = model.predict(img_open1)
ypred_open2 = model.predict(img_open2)

# %%
figure = plt.figure(figsize=(2, 2))
img_closed1 = np.squeeze(img_closed1, axis=0)
plt.imshow(img_closed1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_closed2 = np.squeeze(img_closed2, axis=0)
plt.imshow(img_closed2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed2[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open1 = np.squeeze(img_open1, axis=0)
plt.imshow(img_open1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open2 = np.squeeze(img_open2, axis=0)
plt.imshow(img_open2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open2[0], axis=0)]}')
plt.show()

# %%
keras_model = tf.keras.models.load_model("/content/drive/MyDrive/driver_drowsiness_detection_modified/model/Driver_Drowsiness_Detection.h5")
converter = tf.lite.TFLiteConverter.from_keras_model(keras_model)

tfmodel = converter.convert()
open ("/content/drive/MyDrive/driver_drowsiness_detection_modified/model/model.tflite" , "wb") .write(tfmodel)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpzrhvu7dz/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 916992
